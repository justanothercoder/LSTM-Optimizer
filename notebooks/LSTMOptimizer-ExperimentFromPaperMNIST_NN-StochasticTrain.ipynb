# %%
import theano
import theano.tensor as T
import lasagne as L

from theano.printing import Print as TPP

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import time
from IPython import display

from util import iterate_minibatches
from loadmnist import load_data

# %matplotlib inline
# Out:
# Using gpu device 0: Tesla M2090 (CNMeM is disabled, cuDNN not available)

# %%
input_var = T.vector()

# %%
X_train, y_train, X_val, y_val = load_data(test_size=0.2)

# %%
class NeuralNetwork:
    def __init__(self, n_input, n_hidden, n_target, theta=None, input_var=None, target_var=None):
        self.input_var = input_var or T.matrix('mnist input')
        self.target_var = target_var or T.ivector('mnist target')

        self.theta = theta or T.vector('theta')
        
        self.W1 = T.reshape(self.theta[:n_input * n_hidden], (n_input, n_hidden))
        self.b1 = self.theta[n_input * n_hidden:(n_input + 1) * n_hidden]
        self.W2 = T.reshape(self.theta[(n_input + 1) * n_hidden:(n_input + 1) * n_hidden + n_hidden * n_target], (n_hidden, n_target))
        self.b2 = self.theta[(n_input + 1) * n_hidden + n_hidden * n_target:(n_input + 1) * n_hidden + (n_hidden + 1) * n_target]

        l_input = L.layers.InputLayer(shape=(None, n_input), input_var=input_var)
        l_dense = L.layers.DenseLayer(l_input, 
                                      num_units=n_hidden, 
                                      W=self.W1, b=self.b1,
                                      nonlinearity=L.nonlinearities.sigmoid)
        l_softmax = L.layers.DenseLayer(l_dense,
                                       num_units=n_target,
                                       W=self.W2, b=self.b2,
                                       nonlinearity=L.nonlinearities.softmax)
        
        prediction = L.layers.get_output(l_softmax)
        prediction = T.clip(prediction, 1e-5, 1. - 1e-5)
        self.loss = L.objectives.categorical_crossentropy(prediction, self.target_var).mean()
        
        self.func = self.loss
        self.grad = theano.grad(self.func, self.theta)
        
        self.params = [self.input_var, self.target_var]

# %%
mnist_input_var = T.matrix('mnist input')
mnist_target_var = T.ivector('mnist target')
    
n_input = 784
n_hidden = 20
n_target = 10

def func(theta, params):
    input_var = params[:, :-1]
    target_var = params[:, -1].astype('int32')
    
    return NeuralNetwork(n_input, n_hidden, n_target, 
                         theta=theta,
                         input_var=input_var,
                         target_var=target_var).func

mnist_concat = T.concatenate([mnist_input_var, mnist_target_var.astype('float32').dimshuffle(0, 'x')], axis=1)

func = lambda theta: NeuralNetwork(n_input, n_hidden, n_target, 
                                   theta=theta, 
                                   input_var=mnist_input_var, 
                                   target_var=mnist_target_var).func

# %%
new_func = lambda theta: func(theta, mnist_concat)

# %%
# %run stochastic_batch_lstm_optimizer.py

# %%
class LSTMOptimizer:
    def __init__(self, input_var, func, func_params, loss_type='sum', params_input=None, **kwargs):
        n_steps = T.iscalar()    
        
        l_input = L.layers.InputLayer(shape=(None,), input_var=input_var)
        self.l_optim = LSTMOptimizerLayer(l_input, n_steps=n_steps, function=func, params_input=params_input, **kwargs)

        self.params_init = L.layers.get_all_param_values(self.l_optim)
        
        theta_history, loss_history = L.layers.get_output(self.l_optim)
        self.loss_type = loss_type
        if loss_type == 'sum':
            loss = loss_history.sum()
        elif loss_type == 'prod':
            loss = T.log(loss_history).sum()
        elif loss_type == 'weighted_prod':
            loss = (T.log(loss_history) * 0.9**T.arange(loss_history.shape[0])[::-1]).sum()
        else:
            raise ValueError("loss_type should be one of ('sum', 'prod', 'weighted_prod')")
        
        self.lr = theano.shared(np.array(0.01, dtype=np.float32))

        params = L.layers.get_all_params(self.l_optim)
        updates = L.updates.adam(loss, params, learning_rate=self.lr)
        
        self.loss_fn = theano.function([input_var, n_steps] + func_params, [theta_history, loss_history], allow_input_downcast=True)
        self.train_fn = theano.function([input_var, n_steps] + func_params, [theta_history, loss_history], updates=updates, allow_input_downcast=True)

    def reset_network(self):
        L.layers.set_all_param_values(self.l_optim, self.params_init)    
        
    def train(self, sample_function, n_iter=100, n_epochs=50, batch_size=100, decay_rate=0.96):
        optimizer_loss = []
        optimizer_moving_loss = []
        moving_loss = None
        
        for i in range(n_epochs):
            t = time.time()    

            training_loss_history = []
            for j in range(batch_size):
                theta, params = sample_function()
                
                theta_history, loss_history = self.train_fn(theta, n_iter, *params)
                if self.loss_type == 'sum':
                    loss = np.sum(loss_history)
                else:
                    loss = np.sum(np.log(loss_history))
                training_loss_history.append(loss_history)

                optimizer_loss.append(loss)
                if moving_loss is None:
                    moving_loss = loss
                else:
                    moving_loss = 0.9 * moving_loss + 0.1 * loss
                optimizer_moving_loss.append(moving_loss)
                
            display.clear_output(wait=True)
            plt.figure(figsize=(15, 12))
            
            plt.subplot(2, 1, 2)
            plt.semilogy(np.median(training_loss_history, axis=0))
            
            plt.subplot(2, 1, 1)
            if self.loss_type == 'sum':
                plt.semilogy(optimizer_loss, 'b', label='loss')
                plt.semilogy(optimizer_moving_loss, 'r', label='moving loss')
            else:
                plt.plot(optimizer_loss, 'b', label='loss')
                plt.plot(optimizer_moving_loss, 'r', label='moving loss')
            
            plt.show()
            print("Epoch number {}".format(i))
            t = time.time() - t

            print("Time on epoch {}: {}".format(i, t))
            print("Loss on {}: {}; {}".format(i, loss, np.median(training_loss_history, axis=0)[-1]))

            self.lr.set_value((self.lr.get_value() * decay_rate).astype(np.float32))
            
    def optimize(self, theta, func_params, n_iter):
        return self.loss_fn(theta, n_iter, *func_params)
    
    def get_updates(self, loss, params):
        return self.l_optim.get_updates(loss, params)

# %%
def sgd_step(theta, lr):
    f = func(theta)
    g = theano.grad(f, theta)
    return theta - lr * g, f

n_steps = T.iscalar()

sgd_lr = T.scalar()
sgd_thetas, sgd_losses = theano.scan(fn=sgd_step,
                                        outputs_info=[input_var, None],
                                                      non_sequences=sgd_lr,
                                                      n_steps=n_steps)[0]

sgd_fn = theano.function([input_var, n_steps, sgd_lr, mnist_input_var, mnist_target_var], [sgd_thetas, sgd_losses], allow_input_downcast=True)

# %%
def momentum_step(theta, old_grad, lr, mu):
    f = func(theta)
    g = theano.grad(f, theta)
    new_grad = mu * old_grad + TPP('grad:', ('var',))(g)
    return theta - lr * new_grad, f, new_grad

momentum_steps = T.iscalar()
momentum_mu = T.scalar()

momentum_thetas, momentum_losses, _ = theano.scan(fn=momentum_step,
                                                  outputs_info=[input_var, None, T.zeros_like(input_var)],
                                                  non_sequences=[sgd_lr, momentum_mu],
                                                  n_steps=n_steps)[0]

momentum_fn = theano.function([input_var, n_steps, sgd_lr, mnist_input_var, mnist_target_var], [momentum_thetas, momentum_losses], allow_input_downcast=True, givens={
        momentum_mu: np.cast['float32'](0.9),
    })

# %%
lstm_optimizers = {}

options = {
    'num_units': 20, 
    'gradient_steps': 20, 
    'n_layers': 2, 
    'grad_clipping': 0,
    'preprocess_input': True, 
    'scale_output': 0.1,
    
    'n_gac': 5, 
    'loss_type': 'sum',
}

mnist_batches_X_var = T.tensor3()
mnist_batches_y_var = T.matrix()

params_input_X = L.layers.InputLayer(shape=(None, None, n_input), input_var=mnist_batches_X_var)
params_input_y = L.layers.InputLayer(shape=(None, None,), input_var=mnist_batches_y_var.astype('float32'))
params_input_y = L.layers.DimshuffleLayer(params_input_y, (0, 1, 'x'))
params_input = L.layers.ConcatLayer([params_input_X, params_input_y], axis=2)

params_input = None

for n_gac in [0]: #[0, 5]:
    for loss_type in ['sum']: #['sum', 'prod']:
        options['n_gac'] = n_gac
        options['loss_type'] = loss_type
        
        key = "n_gac={}; loss_type={}".format(n_gac, loss_type)
        lstm_optimizers[key] = LSTMOptimizer(input_var, func, [mnist_input_var, mnist_target_var], **options)
#         lstm_optimizers[key] = LSTMOptimizer(input_var, func, [mnist_batches_X_var, mnist_batches_y_var], params_input=params_input, **options)

# %%
class SampleParams:
    def __init__(self, batch_size=128, n_batches=20):
        self.gen = iterate_minibatches(X_train[:128], y_train[:128], batch_size=batch_size, shuffle=True)
        self.batch_size = batch_size
        self.n_batches = n_batches
        
    def __call__(self):
        batches_x = []
        batches_y = []
        
        for _ in range(self.n_batches):
            try:
                ret = next(self.gen)
            except StopIteration:
                self.gen = iterate_minibatches(X_train[:128], y_train[:128], batch_size=self.batch_size, shuffle=True)
                ret = next(self.gen)
                
            batches_x.append(ret[0])
            batches_y.append(ret[1])
            
        return np.array(batches_x), np.array(batches_y)

sample_params = SampleParams(n_batches=20, batch_size=128)
    
def sample_point():
    theta = np.random.normal(loc=0.0, scale=1., size=(n_input + 1) * n_hidden + (n_hidden + 1) * n_target)
    return theta

def sample_point_and_params():
    params = sample_params()
    theta = sample_point()
    
    return theta, params

# %%
class SampleParams:
    def __init__(self, batch_size=128):
        self.gen = iterate_minibatches(X_train, y_train, batch_size=batch_size, shuffle=True)
        self.ret = next(self.gen)
        self.batch_size = batch_size
        
    def __call__(self):
        try:
            ret = next(self.gen)
        except StopIteration:
            self.gen = iterate_minibatches(X_train, y_train, batch_size=self.batch_size, shuffle=True)
            ret = next(self.gen)
            
#         return self.ret
        return ret

sample_params = SampleParams(batch_size=128)
    
def sample_point():
    theta = np.random.normal(loc=0.0, scale=1., size=(n_input + 1) * n_hidden + (n_hidden + 1) * n_target)
    return theta

# def sample_params(ndim=None):
#     ndim = ndim or (np.random.randint(low=0, high=50) + 1)
    
#     W = np.cast['float32'](np.random.randn(ndim, ndim))
#     b = np.cast['float32'](np.random.randn(ndim))
#     return W, b

# def sample_point(ndim):
#     theta = np.cast['float32'](np.random.randn(ndim))
#     return theta

def sample_point_and_params():
    params = sample_params()
    theta = sample_point()
    
    return theta, params

# %%
training_options = {
    'n_iter': 100,
    'n_epochs': 50,
    'batch_size': 100,
    'decay_rate': 0.9,
}

for key, opt in lstm_optimizers.items():
    opt.train(sample_point_and_params, **training_options)
# Out:
# Epoch number 49
# Time on epoch 49: 59.468637466430664
# Loss on 49: 44.433372497558594; 4.334313780418597e-05

# %%
thetas, losses = list(lstm_optimizers.values())[0].optimize(theta, [params[0], params[1]], 1000)
plt.plot(losses, label='lstm')

thetas, losses = momentum_fn(theta, 1000, 0.01, *params)
plt.plot(losses, label='momentum')
# Out:
# grad: var = 8.67734e-05
# grad: var = 8.6054e-05
# grad: var = 8.47057e-05
# grad: var = 8.28253e-05
# grad: var = 8.05119e-05
# grad: var = 8.01486e-05
# grad: var = 7.72047e-05
# grad: var = 7.4096e-05
# grad: var = 7.09055e-05
# grad: var = 6.77061e-05
# grad: var = 6.45599e-05
# grad: var = 6.15183e-05
# grad: var = 5.86225e-05
# grad: var = 5.59028e-05
# grad: var = 5.33773e-05
# grad: var = 5.10502e-05
# grad: var = 4.89107e-05
# grad: var = 4.69345e-05
# grad: var = 4.50882e-05
# grad: var = 4.33336e-05
# grad: var = 4.16341e-05
# grad: var = 3.9958e-05
# grad: var = 3.82823e-05
# grad: var = 3.65942e-05
# grad: var = 3.48912e-05
# grad: var = 3.31807e-05
# grad: var = 3.14775e-05
# grad: var = 2.98006e-05
# grad: var = 2.81689e-05
# grad: var = 2.65981e-05
# grad: var = 2.50994e-05
# grad: var = 2.36789e-05
# grad: var = 2.23396e-05
# grad: var = 2.10824e-05
# grad: var = 1.99075e-05
# grad: var = 1.8815e-05
# grad: var = 1.78046e-05
# grad: var = 1.68753e-05
# grad: var = 1.60256e-05
# grad: var = 1.52525e-05
# grad: var = 1.45522e-05
# grad: var = 1.39202e-05
# grad: var = 1.33508e-05
# grad: var = 1.28381e-05
# grad: var = 1.2376e-05
# grad: var = 1.19582e-05
# grad: var = 1.15787e-05
# grad: var = 1.1232e-05
# grad: var = 1.0913e-05
# grad: var = 1.06172e-05
# grad: var = 1.0341e-05
# grad: var = 1.00812e-05
# grad: var = 9.8352e-06
# grad: var = 9.60118e-06
# grad: var = 9.37763e-06
# grad: var = 9.16346e-06
# grad: var = 8.9579e-06
# grad: var = 8.76041e-06
# grad: var = 8.57064e-06
# grad: var = 8.38835e-06
# grad: var = 8.21337e-06
# grad: var = 8.04555e-06
# grad: var = 7.88478e-06
# grad: var = 7.73091e-06
# grad: var = 7.5838e-06
# grad: var = 7.44324e-06
# grad: var = 7.30904e-06
# grad: var = 7.18092e-06
# grad: var = 7.05862e-06
# grad: var = 6.94183e-06
# grad: var = 6.83021e-06
# grad: var = 6.72343e-06
# grad: var = 6.62114e-06
# grad: var = 6.52299e-06
# grad: var = 6.42863e-06
# grad: var = 6.33772e-06
# grad: var = 6.24994e-06
# grad: var = 6.16497e-06
# grad: var = 6.08255e-06
# grad: var = 6.0024e-06
# grad: var = 5.92429e-06
# grad: var = 5.84801e-06
# grad: var = 5.77339e-06
# grad: var = 5.70026e-06
# grad: var = 5.62851e-06
# grad: var = 5.55803e-06
# grad: var = 5.48874e-06
# grad: var = 5.42059e-06
# grad: var = 5.35354e-06
# grad: var = 5.28756e-06
# grad: var = 5.22264e-06
# grad: var = 5.15879e-06
# grad: var = 5.09602e-06
# grad: var = 5.03434e-06
# grad: var = 4.97378e-06
# grad: var = 4.91435e-06
# grad: var = 4.85609e-06
# grad: var = 4.79901e-06
# grad: var = 4.74314e-06
# grad: var = 4.68849e-06
# grad: var = 4.63508e-06
# grad: var = 4.58292e-06
# grad: var = 4.53201e-06
# grad: var = 4.48236e-06
# grad: var = 4.43396e-06
# grad: var = 4.38681e-06
# grad: var = 4.34089e-06
# grad: var = 4.2962e-06
# grad: var = 4.2527e-06
# grad: var = 4.21038e-06
# grad: var = 4.16922e-06
# grad: var = 4.12919e-06
# grad: var = 4.09026e-06
# grad: var = 4.05241e-06
# grad: var = 4.01559e-06
# grad: var = 3.97979e-06
# grad: var = 3.94498e-06
# grad: var = 3.91111e-06
# grad: var = 3.87816e-06
# grad: var = 3.84611e-06
# grad: var = 3.81491e-06
# grad: var = 3.78455e-06
# grad: var = 3.75498e-06
# grad: var = 3.7262e-06
# grad: var = 3.69816e-06
# grad: var = 3.67084e-06
# grad: var = 3.64422e-06
# grad: var = 3.61826e-06
# grad: var = 3.59296e-06
# grad: var = 3.56827e-06
# grad: var = 3.54419e-06
# grad: var = 3.52068e-06
# grad: var = 3.49773e-06
# grad: var = 3.47531e-06
# grad: var = 3.4534e-06
# grad: var = 3.43198e-06
# grad: var = 3.41104e-06
# grad: var = 3.39054e-06
# grad: var = 3.37047e-06
# grad: var = 3.35081e-06
# grad: var = 3.33154e-06
# grad: var = 3.31264e-06
# grad: var = 3.29409e-06
# grad: var = 3.27587e-06
# grad: var = 3.25795e-06
# grad: var = 3.24033e-06
# grad: var = 3.22297e-06
# grad: var = 3.20586e-06
# grad: var = 3.18897e-06
# grad: var = 3.17229e-06
# grad: var = 3.1558e-06
# grad: var = 3.13947e-06
# grad: var = 3.12329e-06
# grad: var = 3.10723e-06
# grad: var = 3.09127e-06
# grad: var = 3.07541e-06
# grad: var = 3.05962e-06
# grad: var = 3.04388e-06
# grad: var = 3.02819e-06
# grad: var = 3.01252e-06
# grad: var = 2.99687e-06
# grad: var = 2.98123e-06
# grad: var = 2.96559e-06
# grad: var = 2.94994e-06
# grad: var = 2.93429e-06
# grad: var = 2.91863e-06
# grad: var = 2.90296e-06
# grad: var = 2.88729e-06
# grad: var = 2.87161e-06
# grad: var = 2.85594e-06
# grad: var = 2.84029e-06
# grad: var = 2.82465e-06
# grad: var = 2.80905e-06
# grad: var = 2.7935e-06
# grad: var = 2.778e-06
# grad: var = 2.76256e-06
# grad: var = 2.74721e-06
# grad: var = 2.73194e-06
# grad: var = 2.71678e-06
# grad: var = 2.70172e-06
# grad: var = 2.6868e-06
# grad: var = 2.672e-06
# grad: var = 2.65734e-06
# grad: var = 2.64284e-06
# grad: var = 2.62849e-06
# grad: var = 2.6143e-06
# grad: var = 2.60028e-06
# grad: var = 2.58643e-06
# grad: var = 2.57275e-06
# grad: var = 2.55925e-06
# grad: var = 2.54592e-06
# grad: var = 2.53277e-06
# grad: var = 2.51979e-06
# grad: var = 2.50698e-06
# grad: var = 2.49433e-06
# grad: var = 2.48185e-06
# grad: var = 2.46952e-06
# grad: var = 2.45733e-06
# grad: var = 2.44529e-06
# grad: var = 2.43339e-06
# grad: var = 2.42161e-06
# grad: var = 2.40994e-06
# grad: var = 2.39838e-06
# grad: var = 2.38692e-06
# grad: var = 2.37555e-06
# grad: var = 2.36425e-06
# grad: var = 2.35303e-06
# grad: var = 2.34186e-06
# grad: var = 2.33074e-06
# grad: var = 2.31966e-06
# grad: var = 2.30862e-06
# grad: var = 2.2976e-06
# grad: var = 2.28661e-06
# grad: var = 2.27563e-06
# grad: var = 2.26466e-06
# grad: var = 2.2537e-06
# grad: var = 2.24274e-06
# grad: var = 2.2318e-06
# grad: var = 2.22086e-06
# grad: var = 2.20994e-06
# grad: var = 2.19903e-06
# grad: var = 2.18814e-06
# grad: var = 2.17727e-06
# grad: var = 2.16643e-06
# grad: var = 2.15564e-06
# grad: var = 2.14489e-06
# grad: var = 2.1342e-06
# grad: var = 2.12357e-06
# grad: var = 2.11301e-06
# grad: var = 2.10253e-06
# grad: var = 2.09214e-06
# grad: var = 2.08185e-06
# grad: var = 2.07166e-06
# grad: var = 2.06158e-06
# grad: var = 2.05161e-06
# grad: var = 2.04177e-06
# grad: var = 2.03205e-06
# grad: var = 2.02246e-06
# grad: var = 2.013e-06
# grad: var = 2.00367e-06
# grad: var = 1.99447e-06
# grad: var = 1.98539e-06
# grad: var = 1.97645e-06
# grad: var = 1.96764e-06
# grad: var = 1.95895e-06
# grad: var = 1.95039e-06
# grad: var = 1.94194e-06
# grad: var = 1.9336e-06
# grad: var = 1.92538e-06
# grad: var = 1.91725e-06
# grad: var = 1.90923e-06
# grad: var = 1.9013e-06
# grad: var = 1.89346e-06
# grad: var = 1.88569e-06
# grad: var = 1.878e-06
# grad: var = 1.87038e-06
# grad: var = 1.86283e-06
# grad: var = 1.85533e-06
# grad: var = 1.84788e-06
# grad: var = 1.84047e-06
# grad: var = 1.8331e-06
# grad: var = 1.82576e-06
# grad: var = 1.81844e-06
# grad: var = 1.81115e-06
# grad: var = 1.80386e-06
# grad: var = 1.79659e-06
# grad: var = 1.78931e-06
# grad: var = 1.78203e-06
# grad: var = 1.77474e-06
# grad: var = 1.76744e-06
# grad: var = 1.76012e-06
# grad: var = 1.75277e-06
# grad: var = 1.7454e-06
# grad: var = 1.738e-06
# grad: var = 1.73057e-06
# grad: var = 1.7231e-06
# grad: var = 1.7156e-06
# grad: var = 1.70805e-06
# grad: var = 1.70048e-06
# grad: var = 1.69286e-06
# grad: var = 1.6852e-06
# grad: var = 1.67751e-06
# grad: var = 1.66979e-06
# grad: var = 1.66203e-06
# grad: var = 1.65424e-06
# grad: var = 1.64643e-06
# grad: var = 1.63859e-06
# grad: var = 1.63073e-06
# grad: var = 1.62286e-06
# grad: var = 1.61498e-06
# grad: var = 1.60708e-06
# grad: var = 1.59919e-06
# grad: var = 1.5913e-06
# grad: var = 1.58341e-06
# grad: var = 1.57553e-06
# grad: var = 1.56767e-06
# grad: var = 1.55982e-06
# grad: var = 1.552e-06
# grad: var = 1.54421e-06
# grad: var = 1.53644e-06
# grad: var = 1.52871e-06
# grad: var = 1.52101e-06
# grad: var = 1.51336e-06
# grad: var = 1.50574e-06
# grad: var = 1.49817e-06
# grad: var = 1.49065e-06
# grad: var = 1.48318e-06
# grad: var = 1.47575e-06
# grad: var = 1.46838e-06
# grad: var = 1.46107e-06
# grad: var = 1.45381e-06
# grad: var = 1.4466e-06
# grad: var = 1.43946e-06
# grad: var = 1.43237e-06
# grad: var = 1.42534e-06
# grad: var = 1.41837e-06
# grad: var = 1.41146e-06
# grad: var = 1.40462e-06
# grad: var = 1.39783e-06
# grad: var = 1.3911e-06
# grad: var = 1.38444e-06
# grad: var = 1.37783e-06
# grad: var = 1.37129e-06
# grad: var = 1.36481e-06
# grad: var = 1.35838e-06
# grad: var = 1.35202e-06
# grad: var = 1.34571e-06
# grad: var = 1.33947e-06
# grad: var = 1.33328e-06
# grad: var = 1.32714e-06
# grad: var = 1.32106e-06
# grad: var = 1.31504e-06
# grad: var = 1.30906e-06
# grad: var = 1.30314e-06
# grad: var = 1.29727e-06
# grad: var = 1.29145e-06
# grad: var = 1.28567e-06
# grad: var = 1.27994e-06
# grad: var = 1.27425e-06
# grad: var = 1.26861e-06
# grad: var = 1.26301e-06
# grad: var = 1.25744e-06
# grad: var = 1.25192e-06
# grad: var = 1.24642e-06
# grad: var = 1.24097e-06
# grad: var = 1.23554e-06
# grad: var = 1.23014e-06
# grad: var = 1.22478e-06
# grad: var = 1.21944e-06
# grad: var = 1.21412e-06
# grad: var = 1.20883e-06
# grad: var = 1.20356e-06
# grad: var = 1.19832e-06
# grad: var = 1.19309e-06
# grad: var = 1.18789e-06
# grad: var = 1.1827e-06
# grad: var = 1.17753e-06
# grad: var = 1.17238e-06
# grad: var = 1.16724e-06
# grad: var = 1.16212e-06
# grad: var = 1.15702e-06
# grad: var = 1.15193e-06
# grad: var = 1.14686e-06
# grad: var = 1.1418e-06
# grad: var = 1.13677e-06
# grad: var = 1.13175e-06
# grad: var = 1.12675e-06
# grad: var = 1.12176e-06
# grad: var = 1.1168e-06
# grad: var = 1.11186e-06
# grad: var = 1.10694e-06
# grad: var = 1.10204e-06
# grad: var = 1.09717e-06
# grad: var = 1.09232e-06
# grad: var = 1.0875e-06
# grad: var = 1.08271e-06
# grad: var = 1.07794e-06
# grad: var = 1.07321e-06
# grad: var = 1.06851e-06
# grad: var = 1.06384e-06
# grad: var = 1.05921e-06
# grad: var = 1.05461e-06
# grad: var = 1.05005e-06
# grad: var = 1.04552e-06
# grad: var = 1.04104e-06
# grad: var = 1.03659e-06
# grad: var = 1.03218e-06
# grad: var = 1.02782e-06
# grad: var = 1.0235e-06
# grad: var = 1.01922e-06
# grad: var = 1.01498e-06
# grad: var = 1.01079e-06
# grad: var = 1.00664e-06
# grad: var = 1.00254e-06
# grad: var = 9.98482e-07
# grad: var = 9.9447e-07
# grad: var = 9.90503e-07
# grad: var = 9.86582e-07
# grad: var = 9.82707e-07
# grad: var = 9.78878e-07
# grad: var = 9.75094e-07
# grad: var = 9.71357e-07
# grad: var = 9.67664e-07
# grad: var = 9.64018e-07
# grad: var = 9.60416e-07
# grad: var = 9.56859e-07
# grad: var = 9.53347e-07
# grad: var = 9.49879e-07
# grad: var = 9.46454e-07
# grad: var = 9.43072e-07
# grad: var = 9.39734e-07
# grad: var = 9.36436e-07
# grad: var = 9.33181e-07
# grad: var = 9.29967e-07
# grad: var = 9.26792e-07
# grad: var = 9.23657e-07
# grad: var = 9.2056e-07
# grad: var = 9.17501e-07
# grad: var = 9.1448e-07
# grad: var = 9.11494e-07
# grad: var = 9.08544e-07
# grad: var = 9.05628e-07
# grad: var = 9.02745e-07
# grad: var = 8.99895e-07
# grad: var = 8.97076e-07
# grad: var = 8.94286e-07
# grad: var = 8.91527e-07
# grad: var = 8.88795e-07
# grad: var = 8.86091e-07
# grad: var = 8.83412e-07
# grad: var = 8.80758e-07
# grad: var = 8.78127e-07
# grad: var = 8.75519e-07
# grad: var = 8.72932e-07
# grad: var = 8.70364e-07
# grad: var = 8.67815e-07
# grad: var = 8.65284e-07
# grad: var = 8.62768e-07
# grad: var = 8.60268e-07
# grad: var = 8.57781e-07
# grad: var = 8.55307e-07
# grad: var = 8.52844e-07
# grad: var = 8.50391e-07
# grad: var = 8.47946e-07
# grad: var = 8.45509e-07
# grad: var = 8.43079e-07
# grad: var = 8.40654e-07
# grad: var = 8.38233e-07
# grad: var = 8.35815e-07
# grad: var = 8.33399e-07
# grad: var = 8.30985e-07
# grad: var = 8.2857e-07
# grad: var = 8.26155e-07
# grad: var = 8.23739e-07
# grad: var = 8.21319e-07
# grad: var = 8.18897e-07
# grad: var = 8.16471e-07
# grad: var = 8.14041e-07
# grad: var = 8.11605e-07
# grad: var = 8.09165e-07
# grad: var = 8.06718e-07
# grad: var = 8.04265e-07
# grad: var = 8.01806e-07
# grad: var = 7.9934e-07
# grad: var = 7.96867e-07
# grad: var = 7.94388e-07
# grad: var = 7.91902e-07
# grad: var = 7.8941e-07
# grad: var = 7.86911e-07
# grad: var = 7.84405e-07
# grad: var = 7.81895e-07
# grad: var = 7.79378e-07
# grad: var = 7.76857e-07
# grad: var = 7.74332e-07
# grad: var = 7.71802e-07
# grad: var = 7.6927e-07
# grad: var = 7.66735e-07
# grad: var = 7.64199e-07
# grad: var = 7.61662e-07
# grad: var = 7.59125e-07
# grad: var = 7.56588e-07
# grad: var = 7.54054e-07
# grad: var = 7.51522e-07
# grad: var = 7.48994e-07
# grad: var = 7.46471e-07
# grad: var = 7.43954e-07
# grad: var = 7.41443e-07
# grad: var = 7.3894e-07
# grad: var = 7.36445e-07
# grad: var = 7.3396e-07
# grad: var = 7.31486e-07
# grad: var = 7.29023e-07
# grad: var = 7.26573e-07
# grad: var = 7.24136e-07
# grad: var = 7.21713e-07
# grad: var = 7.19306e-07
# grad: var = 7.16914e-07
# grad: var = 7.14539e-07
# grad: var = 7.12181e-07
# grad: var = 7.09842e-07
# grad: var = 7.07521e-07
# grad: var = 7.0522e-07
# grad: var = 7.02939e-07
# grad: var = 7.00678e-07
# grad: var = 6.98439e-07
# grad: var = 6.96221e-07
# grad: var = 6.94025e-07
# grad: var = 6.91852e-07
# grad: var = 6.89701e-07
# grad: var = 6.87574e-07
# grad: var = 6.85469e-07
# grad: var = 6.83389e-07
# grad: var = 6.81332e-07
# grad: var = 6.79299e-07
# grad: var = 6.77291e-07
# grad: var = 6.75307e-07
# grad: var = 6.73348e-07
# grad: var = 6.71413e-07
# grad: var = 6.69502e-07
# grad: var = 6.67617e-07
# grad: var = 6.65756e-07
# grad: var = 6.6392e-07
# grad: var = 6.62109e-07
# grad: var = 6.60322e-07
# grad: var = 6.58561e-07
# grad: var = 6.56824e-07
# grad: var = 6.55111e-07
# grad: var = 6.53423e-07
# grad: var = 6.5176e-07
# grad: var = 6.50121e-07
# grad: var = 6.48507e-07
# grad: var = 6.46917e-07
# grad: var = 6.4535e-07
# grad: var = 6.43809e-07
# grad: var = 6.42291e-07
# grad: var = 6.40797e-07
# grad: var = 6.39326e-07
# grad: var = 6.3788e-07
# grad: var = 6.36457e-07
# grad: var = 6.35058e-07
# grad: var = 6.33681e-07
# grad: var = 6.32329e-07
# grad: var = 6.30999e-07
# grad: var = 6.29693e-07
# grad: var = 6.28409e-07
# grad: var = 6.27149e-07
# grad: var = 6.25911e-07
# grad: var = 6.24695e-07
# grad: var = 6.23503e-07
# grad: var = 6.22332e-07
# grad: var = 6.21184e-07
# grad: var = 6.20058e-07
# grad: var = 6.18954e-07
# grad: var = 6.17872e-07
# grad: var = 6.16811e-07
# grad: var = 6.15773e-07
# grad: var = 6.14755e-07
# grad: var = 6.13759e-07
# grad: var = 6.12784e-07
# grad: var = 6.11831e-07
# grad: var = 6.10898e-07
# grad: var = 6.09985e-07
# grad: var = 6.09094e-07
# grad: var = 6.08222e-07
# grad: var = 6.0737e-07
# grad: var = 6.06539e-07
# grad: var = 6.05727e-07
# grad: var = 6.04934e-07
# grad: var = 6.0416e-07
# grad: var = 6.03406e-07
# grad: var = 6.02669e-07
# grad: var = 6.01951e-07
# grad: var = 6.01251e-07
# grad: var = 6.00569e-07
# grad: var = 5.99904e-07
# grad: var = 5.99256e-07
# grad: var = 5.98625e-07
# grad: var = 5.98009e-07
# grad: var = 5.9741e-07
# grad: var = 5.96825e-07
# grad: var = 5.96256e-07
# grad: var = 5.95701e-07
# grad: var = 5.9516e-07
# grad: var = 5.94633e-07
# grad: var = 5.94118e-07
# grad: var = 5.93616e-07
# grad: var = 5.93126e-07
# grad: var = 5.92648e-07
# grad: var = 5.92181e-07
# grad: var = 5.91724e-07
# grad: var = 5.91276e-07
# grad: var = 5.90838e-07
# grad: var = 5.90409e-07
# grad: var = 5.89988e-07
# grad: var = 5.89575e-07
# grad: var = 5.89169e-07
# grad: var = 5.8877e-07
# grad: var = 5.88376e-07
# grad: var = 5.87988e-07
# grad: var = 5.87606e-07
# grad: var = 5.87227e-07
# grad: var = 5.86853e-07
# grad: var = 5.86483e-07
# grad: var = 5.86116e-07
# grad: var = 5.85752e-07
# grad: var = 5.85391e-07
# grad: var = 5.85031e-07
# grad: var = 5.84674e-07
# grad: var = 5.84319e-07
# grad: var = 5.83965e-07
# grad: var = 5.83613e-07
# grad: var = 5.83261e-07
# grad: var = 5.82911e-07
# grad: var = 5.82563e-07
# grad: var = 5.82215e-07
# grad: var = 5.81868e-07
# grad: var = 5.81522e-07
# grad: var = 5.81178e-07
# grad: var = 5.80835e-07
# grad: var = 5.80494e-07
# grad: var = 5.80155e-07
# grad: var = 5.79817e-07
# grad: var = 5.79482e-07
# grad: var = 5.79149e-07
# grad: var = 5.78819e-07
# grad: var = 5.78492e-07
# grad: var = 5.78168e-07
# grad: var = 5.77848e-07
# grad: var = 5.77532e-07
# grad: var = 5.7722e-07
# grad: var = 5.76912e-07
# grad: var = 5.7661e-07
# grad: var = 5.76312e-07
# grad: var = 5.76019e-07
# grad: var = 5.75731e-07
# grad: var = 5.75448e-07
# grad: var = 5.75171e-07
# grad: var = 5.749e-07
# grad: var = 5.74633e-07
# grad: var = 5.74372e-07
# grad: var = 5.74116e-07
# grad: var = 5.73864e-07
# grad: var = 5.73617e-07
# grad: var = 5.73374e-07
# grad: var = 5.73135e-07
# grad: var = 5.72899e-07
# grad: var = 5.72665e-07
# grad: var = 5.72433e-07
# grad: var = 5.72201e-07
# grad: var = 5.7197e-07
# grad: var = 5.71738e-07
# grad: var = 5.71503e-07
# grad: var = 5.71266e-07
# grad: var = 5.71024e-07
# grad: var = 5.70777e-07
# grad: var = 5.70524e-07
# grad: var = 5.70262e-07
# grad: var = 5.6999e-07
# grad: var = 5.69708e-07
# grad: var = 5.69413e-07
# grad: var = 5.69104e-07
# grad: var = 5.6878e-07
# grad: var = 5.6844e-07
# grad: var = 5.68081e-07
# grad: var = 5.67701e-07
# grad: var = 5.67302e-07
# grad: var = 5.66879e-07
# grad: var = 5.66433e-07
# grad: var = 5.65961e-07
# grad: var = 5.65464e-07
# grad: var = 5.64939e-07
# grad: var = 5.64386e-07
# grad: var = 5.63805e-07
# grad: var = 5.63194e-07
# grad: var = 5.62552e-07
# grad: var = 5.6188e-07
# grad: var = 5.61178e-07
# grad: var = 5.60444e-07
# grad: var = 5.59678e-07
# grad: var = 5.58882e-07
# grad: var = 5.58056e-07
# grad: var = 5.57199e-07
# grad: var = 5.56311e-07
# grad: var = 5.55395e-07
# grad: var = 5.5445e-07
# grad: var = 5.53477e-07
# grad: var = 5.52477e-07
# grad: var = 5.51451e-07
# grad: var = 5.504e-07
# grad: var = 5.49324e-07
# grad: var = 5.48226e-07
# grad: var = 5.47106e-07
# grad: var = 5.45965e-07
# grad: var = 5.44804e-07
# grad: var = 5.43625e-07
# grad: var = 5.42428e-07
# grad: var = 5.41214e-07
# grad: var = 5.39985e-07
# grad: var = 5.38742e-07
# grad: var = 5.37486e-07
# grad: var = 5.36217e-07
# grad: var = 5.34936e-07
# grad: var = 5.33645e-07
# grad: var = 5.32344e-07
# grad: var = 5.31034e-07
# grad: var = 5.29716e-07
# grad: var = 5.2839e-07
# grad: var = 5.27057e-07
# grad: var = 5.25719e-07
# grad: var = 5.24374e-07
# grad: var = 5.23025e-07
# grad: var = 5.21671e-07
# grad: var = 5.20314e-07
# grad: var = 5.18953e-07
# grad: var = 5.17589e-07
# grad: var = 5.16223e-07
# grad: var = 5.14856e-07
# grad: var = 5.13487e-07
# grad: var = 5.12117e-07
# grad: var = 5.10747e-07
# grad: var = 5.09376e-07
# grad: var = 5.08007e-07
# grad: var = 5.06637e-07
# grad: var = 5.05269e-07
# grad: var = 5.03903e-07
# grad: var = 5.02539e-07
# grad: var = 5.01177e-07
# grad: var = 4.99818e-07
# grad: var = 4.98461e-07
# grad: var = 4.97108e-07
# grad: var = 4.95758e-07
# grad: var = 4.94413e-07
# grad: var = 4.93071e-07
# grad: var = 4.91734e-07
# grad: var = 4.90402e-07
# grad: var = 4.89075e-07
# grad: var = 4.87752e-07
# grad: var = 4.86435e-07
# grad: var = 4.85124e-07
# grad: var = 4.83818e-07
# grad: var = 4.82518e-07
# grad: var = 4.81224e-07
# grad: var = 4.79936e-07
# grad: var = 4.78654e-07
# grad: var = 4.77378e-07
# grad: var = 4.76109e-07
# grad: var = 4.74846e-07
# grad: var = 4.73589e-07
# grad: var = 4.72339e-07
# grad: var = 4.71095e-07
# grad: var = 4.69858e-07
# grad: var = 4.68628e-07
# grad: var = 4.67403e-07
# grad: var = 4.66185e-07
# grad: var = 4.64974e-07
# grad: var = 4.63769e-07
# grad: var = 4.6257e-07
# grad: var = 4.61377e-07
# grad: var = 4.6019e-07
# grad: var = 4.5901e-07
# grad: var = 4.57836e-07
# grad: var = 4.56667e-07
# grad: var = 4.55504e-07
# grad: var = 4.54347e-07
# grad: var = 4.53196e-07
# grad: var = 4.5205e-07
# grad: var = 4.5091e-07
# grad: var = 4.49775e-07
# grad: var = 4.48645e-07
# grad: var = 4.47521e-07
# grad: var = 4.46401e-07
# grad: var = 4.45287e-07
# grad: var = 4.44177e-07
# grad: var = 4.43072e-07
# grad: var = 4.41972e-07
# grad: var = 4.40876e-07
# grad: var = 4.39785e-07
# grad: var = 4.38698e-07
# grad: var = 4.37615e-07
# grad: var = 4.36537e-07
# grad: var = 4.35463e-07
# grad: var = 4.34393e-07
# grad: var = 4.33327e-07
# grad: var = 4.32264e-07
# grad: var = 4.31206e-07
# grad: var = 4.30151e-07
# grad: var = 4.291e-07
# grad: var = 4.28053e-07
# grad: var = 4.27009e-07
# grad: var = 4.25969e-07
# grad: var = 4.24933e-07
# grad: var = 4.239e-07
# grad: var = 4.2287e-07
# grad: var = 4.21844e-07
# grad: var = 4.20821e-07
# grad: var = 4.19802e-07
# grad: var = 4.18786e-07
# grad: var = 4.17774e-07
# grad: var = 4.16764e-07
# grad: var = 4.15759e-07
# grad: var = 4.14756e-07
# grad: var = 4.13757e-07
# grad: var = 4.12762e-07
# grad: var = 4.1177e-07
# grad: var = 4.10781e-07
# grad: var = 4.09796e-07
# grad: var = 4.08814e-07
# grad: var = 4.07836e-07
# grad: var = 4.06861e-07
# grad: var = 4.0589e-07
# grad: var = 4.04922e-07
# grad: var = 4.03958e-07
# grad: var = 4.02998e-07
# grad: var = 4.02042e-07
# grad: var = 4.01089e-07
# grad: var = 4.0014e-07
# grad: var = 3.99195e-07
# grad: var = 3.98253e-07
# grad: var = 3.97316e-07
# grad: var = 3.96383e-07
# grad: var = 3.95453e-07
# grad: var = 3.94528e-07
# grad: var = 3.93606e-07
# grad: var = 3.92689e-07
# grad: var = 3.91776e-07
# grad: var = 3.90868e-07
# grad: var = 3.89963e-07
# grad: var = 3.89063e-07
# grad: var = 3.88167e-07
# grad: var = 3.87275e-07
# grad: var = 3.86388e-07
# grad: var = 3.85506e-07
# grad: var = 3.84627e-07
# grad: var = 3.83753e-07
# grad: var = 3.82884e-07
# grad: var = 3.82019e-07
# grad: var = 3.81159e-07
# grad: var = 3.80304e-07
# grad: var = 3.79452e-07
# grad: var = 3.78606e-07
# grad: var = 3.77764e-07
# grad: var = 3.76927e-07
# grad: var = 3.76094e-07
# grad: var = 3.75266e-07
# grad: var = 3.74443e-07
# grad: var = 3.73624e-07
# grad: var = 3.72809e-07
# grad: var = 3.72e-07
# grad: var = 3.71195e-07
# grad: var = 3.70394e-07
# grad: var = 3.69598e-07
# grad: var = 3.68806e-07
# grad: var = 3.68019e-07
# grad: var = 3.67236e-07
# grad: var = 3.66457e-07
# grad: var = 3.65683e-07
# grad: var = 3.64913e-07
# grad: var = 3.64148e-07
# grad: var = 3.63386e-07
# grad: var = 3.62629e-07
# grad: var = 3.61876e-07
# grad: var = 3.61126e-07
# grad: var = 3.60381e-07
# grad: var = 3.59639e-07
# grad: var = 3.58901e-07
# grad: var = 3.58167e-07
# grad: var = 3.57437e-07
# grad: var = 3.5671e-07
# grad: var = 3.55986e-07
# grad: var = 3.55266e-07
# grad: var = 3.54549e-07
# grad: var = 3.53835e-07
# grad: var = 3.53124e-07
# grad: var = 3.52416e-07
# grad: var = 3.51712e-07
# grad: var = 3.51009e-07
# grad: var = 3.5031e-07
# grad: var = 3.49613e-07
# grad: var = 3.48918e-07
# grad: var = 3.48226e-07
# grad: var = 3.47536e-07
# grad: var = 3.46848e-07
# grad: var = 3.46162e-07
# grad: var = 3.45478e-07
# grad: var = 3.44796e-07
# grad: var = 3.44115e-07
# grad: var = 3.43437e-07
# grad: var = 3.42759e-07
# grad: var = 3.42083e-07
# grad: var = 3.41408e-07
# grad: var = 3.40734e-07
# grad: var = 3.40062e-07
# grad: var = 3.3939e-07
# grad: var = 3.38719e-07
# grad: var = 3.38049e-07
# grad: var = 3.3738e-07
# grad: var = 3.36711e-07
# grad: var = 3.36043e-07
# grad: var = 3.35375e-07
# grad: var = 3.34708e-07
# grad: var = 3.3404e-07
# grad: var = 3.33374e-07
# grad: var = 3.32707e-07
# grad: var = 3.32041e-07
# grad: var = 3.31374e-07
# grad: var = 3.30708e-07
# grad: var = 3.30042e-07
# grad: var = 3.29376e-07
# grad: var = 3.28709e-07
# grad: var = 3.28043e-07
# grad: var = 3.27377e-07
# grad: var = 3.2671e-07
# grad: var = 3.26044e-07
# grad: var = 3.25377e-07
# grad: var = 3.24711e-07
# grad: var = 3.24044e-07
# grad: var = 3.23378e-07
# grad: var = 3.22711e-07
# grad: var = 3.22045e-07
# grad: var = 3.21378e-07
# grad: var = 3.20712e-07
# grad: var = 3.20046e-07
# grad: var = 3.1938e-07
# grad: var = 3.18714e-07
# grad: var = 3.18048e-07
# grad: var = 3.17383e-07
# grad: var = 3.16719e-07
# grad: var = 3.16054e-07
# grad: var = 3.15391e-07
# grad: var = 3.14728e-07
# grad: var = 3.14065e-07
# grad: var = 3.13404e-07
# grad: var = 3.12743e-07
# grad: var = 3.12083e-07
# grad: var = 3.11424e-07
# grad: var = 3.10766e-07
# grad: var = 3.10109e-07
# grad: var = 3.09454e-07
# grad: var = 3.08799e-07
# grad: var = 3.08146e-07
# grad: var = 3.07495e-07
# grad: var = 3.06845e-07
# grad: var = 3.06196e-07
# grad: var = 3.05549e-07
# grad: var = 3.04904e-07
# grad: var = 3.0426e-07
# grad: var = 3.03619e-07
# grad: var = 3.02979e-07
# grad: var = 3.02341e-07
# grad: var = 3.01705e-07
# grad: var = 3.01071e-07
# grad: var = 3.00439e-07
# grad: var = 2.99809e-07
# grad: var = 2.99182e-07
# grad: var = 2.98557e-07
# grad: var = 2.97934e-07
# grad: var = 2.97313e-07
# grad: var = 2.96695e-07
# grad: var = 2.96079e-07
# grad: var = 2.95466e-07
# grad: var = 2.94855e-07
# grad: var = 2.94247e-07
# grad: var = 2.93641e-07
# grad: var = 2.93038e-07
# grad: var = 2.92437e-07
# grad: var = 2.91839e-07
# grad: var = 2.91244e-07
# grad: var = 2.90651e-07
# grad: var = 2.90061e-07
# grad: var = 2.89474e-07
# grad: var = 2.88889e-07
# grad: var = 2.88307e-07
# grad: var = 2.87728e-07
# grad: var = 2.87152e-07
# grad: var = 2.86578e-07
# grad: var = 2.86007e-07
# grad: var = 2.85439e-07
# grad: var = 2.84873e-07
# grad: var = 2.84311e-07
# grad: var = 2.83751e-07
# grad: var = 2.83193e-07
# grad: var = 2.82639e-07
# grad: var = 2.82087e-07
# grad: var = 2.81538e-07
# grad: var = 2.80992e-07
# grad: var = 2.80449e-07
# grad: var = 2.79908e-07
# grad: var = 2.7937e-07
# grad: var = 2.78834e-07
# grad: var = 2.78302e-07
# grad: var = 2.77772e-07
# grad: var = 2.77244e-07
# grad: var = 2.7672e-07
# grad: var = 2.76198e-07
# grad: var = 2.75678e-07
# grad: var = 2.75161e-07
# grad: var = 2.74647e-07
# grad: var = 2.74136e-07
# grad: var = 2.73627e-07
# grad: var = 2.7312e-07

# %%
def shared_neural_network(n_input, n_hidden, n_target, theta=None, input_var=None, target_var=None, nonlin=L.nonlinearities.sigmoid, n_layers=2):
    input_var = input_var or T.matrix('mnist input')
    target_var = target_var or T.ivector('mnist target')

    l_input = L.layers.InputLayer(shape=(None, n_input), input_var=input_var)
    l_dense = l_input
    for _ in range(n_layers):
        l_dense = L.layers.DenseLayer(l_dense, 
                                      num_units=n_hidden, 
                                      nonlinearity=nonlin)
    l_softmax = L.layers.DenseLayer(l_dense,
                                   num_units=n_target,
                                   nonlinearity=L.nonlinearities.softmax)

    prediction = L.layers.get_output(l_softmax)
    prediction = T.clip(prediction, 1e-5, 1. - 1e-5)
    loss = L.objectives.categorical_crossentropy(prediction, target_var).mean()
    
    return loss, l_softmax, input_var, target_var

# %%
class SharedNeuralNetwork:
    def __init__(self, n_input, n_hidden, n_target, nonlin=L.nonlinearities.sigmoid, n_layers=1, get_updates=L.updates.adam):
        nn_loss, nn, shared_input_var, shared_target_var = shared_neural_network(n_input, n_hidden, n_target, nonlin=nonlin, n_layers=n_layers)
#        updates = lstm_optimizer.l_optim.get_updates(nn_loss, L.layers.get_all_params(nn))
        updates = get_updates(nn_loss, L.layers.get_all_params(nn))
        
        self.train_shared_nn_fn = theano.function([shared_input_var, shared_target_var], nn_loss, updates=updates, allow_input_downcast=True)
        self.loss_shared_nn_fn = theano.function([shared_input_var, shared_target_var], nn_loss, allow_input_downcast=True)
        self.nn = nn
        
        nn_out = L.layers.get_output(nn)
        nn_out = T.clip(nn_out, 1e-5, 1. - 1e-5)
        nn_accuracy = L.objectives.categorical_accuracy(nn_out, shared_target_var).mean()

        self.accuracy_shared_nn_fn = theano.function([shared_input_var, shared_target_var], nn_accuracy, allow_input_downcast=True)
        self.prediction_shared_nn_fn = theano.function([shared_input_var], nn_out, allow_input_downcast=True)

    def train(self, n_epochs, batch_size):
        train_loss_history = []
        train_loss_av_history = []
        val_loss_history = []

        train_acc_history = []
        val_acc_history = []

        for epoch in range(n_epochs):
            avg_cost = 0
            batches_per_epoch = 0    
            t = time.time()

            for batch in iterate_minibatches(X_train, y_train, batch_size=batch_size, shuffle=True):
                inputs, targets = batch
                cur_loss = self.train_shared_nn_fn(inputs, targets)

                avg_cost += cur_loss
                train_loss_history.append(cur_loss)

                if batches_per_epoch % 50 == 0:
                    print ("Batch number {}".format(batches_per_epoch))

                batches_per_epoch += 1
            avg_cost /= batches_per_epoch
            train_loss_av_history.append(avg_cost)
                
            avg_cost = 0;
            n_batch = 0

            for batch in iterate_minibatches(X_val, y_val, batch_size=batch_size, shuffle=True):
                inputs, targets = batch
                avg_cost += self.loss_shared_nn_fn(inputs, targets)
                n_batch += 1

            avg_cost /= n_batch
            val_loss_history.append(avg_cost)

            train_acc_history.append(self.accuracy_shared_nn_fn(X_train, y_train))
            val_acc_history.append(self.accuracy_shared_nn_fn(X_val, y_val))

            display.clear_output(wait=True)
            plt.subplot(1, 2, 1)
            plt.plot(train_loss_history, label='train loss')
            plt.plot(range(0, len(val_loss_history) * batches_per_epoch, batches_per_epoch), val_loss_history, label='val loss')

            plt.subplot(1, 2, 2)
            plt.plot(train_acc_history, label='train acc')
            plt.plot(val_acc_history, label='val acc')

            plt.show()
            
        return train_loss_history, train_loss_av_history, val_loss_history, train_acc_history, val_acc_history

# %%
parameters = [
    (20, 1, L.nonlinearities.sigmoid),
#     (40, 1, L.nonlinearities.sigmoid),
#     (20, 2, L.nonlinearities.sigmoid),
#     (20, 1, L.nonlinearities.rectify),
]

# updates_list = {
#     'lstm_sum': lstm_optimizer_sum.get_updates,
#     'lstm_gac_sum': lstm_gac_optimizer_sum.get_updates,
#     'lstm_prod': lstm_optimizer.get_updates,
#     'lstm_gac_prod': lstm_gac_optimizer_prod.get_updates,
#     'momentum': lambda loss, params: L.updates.momentum(loss, params, learning_rate=1.0, momentum=0.9),
#     'adam': lambda loss, params: L.updates.adam(loss, params, learning_rate=0.01)
# }

updates_list = {
    name: opt.get_updates 
    for name, opt in lstm_optimizers.items()
}

updates_list['momentum'] = lambda loss, params: L.updates.momentum(loss, params, learning_rate=1.0, momentum=0.9)

histories = {}

nonlins = {
    L.nonlinearities.sigmoid: 'sigmoid',
#     L.nonlinearities.rectify: 'relu'
}

for name, updates in updates_list.items():
    for n_hid, n_layers, nonlin in parameters:
        shared_nn = SharedNeuralNetwork(784, n_hid, 10, nonlin=nonlin, n_layers=n_layers, get_updates=updates)

        batch_size = 128
        n_epochs = 50
        _, train_history, val_history, train_acc_history, val_acc_history = shared_nn.train(n_epochs, batch_size)
        histories["{}; ({}, {}, {})".format(name, n_hid, n_layers, nonlins[nonlin])] = (train_history, val_history, train_acc_history, val_acc_history)

# %%
def plot_with_params(key):
    plt.figure(figsize=(15, 12))

    for name, hist in histories.items():
        train_h, val_h, train_acc_h, val_acc_h = hist

        if name.find(key) == -1:
            continue
        
        if name.find('loss_type') != -1:
            linestyle = '-'
        else:
            linestyle = '--'

        plt.subplot(1, 2, 1)
        plt.title('loss; {}'.format(key))
        plt.semilogy(train_h, label='train loss; {}'.format(name), linestyle=linestyle)
        plt.semilogy(val_h, label='val loss; {}'.format(name), linestyle=linestyle)
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.title('accuracy; {}'.format(key))
        plt.plot(train_acc_h, label='train accuracy; {}'.format(name), linestyle=linestyle)
        plt.plot(val_acc_h, label='val accuracy; {}'.format(name), linestyle=linestyle)
        plt.legend(loc=4)

    plt.show()

# %%
key = "({}, {}, {})".format(20, 1, 'sigmoid')
plot_with_params(key)

# %%
key = "({}, {}, {})".format(40, 1, 'sigmoid')
plot_with_params(key)

# %%
key = "({}, {}, {})".format(20, 2, 'sigmoid')
plot_with_params(key)

# %%
key = "({}, {}, {})".format(20, 1, 'relu')
plot_with_params(key)
