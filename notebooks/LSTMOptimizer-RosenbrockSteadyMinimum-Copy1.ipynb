# %%
import theano
import theano.tensor as T
import lasagne as L

from theano.printing import Print as TPP

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using gpu device 0: Tesla M2090 (CNMeM is disabled, cuDNN not available)

# %%
# %run lstm_optimizer.py

# %%
input_var = T.vector()

# %%
from theano.tensor.shared_randomstreams import RandomStreams
rng = RandomStreams(seed=42)

class QuadraticFunction:
    def __init__(self, theta=None, W=None, b=None):
        self.W = W or T.matrix('W')
        self.b = b or T.vector('b')
#        self.W = W or rng.normal(avg=0., std=1.0, size=(theta.shape[0], theta.shape[0]))
#        self.b = b or rng.normal(avg=0., std=1.0, size=(theta.shape[0],))
    
        self.theta = theta or T.vector('theta')
        
        self.func = ((T.dot(self.W, self.theta) - self.b)**2).sum() / 100.0
        self.grad = theano.grad(self.func, self.theta)
        
        self.params = [self.W, self.b]
        
class RosenbrockFunction:
    def __init__(self, theta=None, a=None, b=None):
        self.a = a or T.scalar('a')
        self.b = b or T.scalar('b')
        self.theta = theta or T.vector('theta')
        
        self.func = ( (self.a - self.theta[0])**2 + self.b * (theta[1] - theta[0]**2)**2 ) / 1000.0
        self.grad = theano.grad(self.func, self.theta)
        
        self.params = [self.a, self.b]

# %%
def build_net(func, n_steps, n_hidden=20):
    l_input = L.layers.InputLayer(shape=(None,), input_var=input_var)
    l_optim = LSTMOptimizerLayer(l_input, num_units=n_hidden, n_steps=n_steps, function=func)
    
    return l_optim

# %%
# W = T.matrix()
# b = T.vector()
    
# func = lambda theta: QuadraticFunction(theta, W, b).func

a = T.scalar()
b = T.scalar()
    
func = lambda theta: RosenbrockFunction(theta, a, b).func

# %%
n_steps = T.iscalar() 
l_optim = build_net(func, n_steps, 100)

theta_history, loss_history = L.layers.get_output(l_optim)
#loss = loss_history.sum()
loss = np.log10(loss_history).sum()

lr = theano.shared(np.array(0.001, dtype=np.float32))

params = L.layers.get_all_params(l_optim)
updates = L.updates.adam(loss, params, learning_rate=lr)

# %%
loss_fn = theano.function([input_var, n_steps, a, b], [theta_history, loss_history], allow_input_downcast=True)
train_fn = theano.function([input_var, n_steps, a, b], [theta_history, loss_history], updates=updates, allow_input_downcast=True)

# %%
def sgd_step(theta, lr):
    f = func(theta)
    g = theano.grad(f, theta)
    return theta - lr * g, f

sgd_lr = T.scalar()
sgd_thetas, sgd_losses = theano.scan(fn=sgd_step,
                                        outputs_info=[input_var, None],
                                                      non_sequences=sgd_lr,
                                                      n_steps=n_steps)[0]

sgd_fn = theano.function([input_var, n_steps, a, b, sgd_lr], [sgd_thetas, sgd_losses], allow_input_downcast=True)

# %%
def momentum_step(theta, old_grad, lr, mu):
    f = func(theta)
    g = theano.grad(f, theta)
    new_grad = mu * old_grad + g
    return theta - lr * g, f, new_grad

momentum_steps = T.iscalar()
momentum_mu = T.scalar()

momentum_thetas, momentum_losses, _ = theano.scan(fn=momentum_step,
                                                  outputs_info=[input_var, None, T.zeros_like(input_var)],
                                                  non_sequences=[sgd_lr, momentum_mu],
                                                  n_steps=n_steps)[0]

momentum_fn = theano.function([input_var, n_steps, a, b, sgd_lr], [momentum_thetas, momentum_losses], allow_input_downcast=True, givens={
        momentum_mu: np.cast['float32'](0.9),
    })

# %%
lr.set_value(0.001)

# %%
from IPython import display
import time

training_loss_history = []

for i in range(20):
    for j in range(100):
        #a_ = np.cast['float32'](np.random.rand() * 10)
        t = time.time()
        a_ = 1.
        b_ = np.cast['float32'](np.random.rand() * 10)
        theta = np.zeros(2, dtype=np.float32)

        theta_history, loss_history = train_fn(theta, 300, a_, b_)
        loss = sum(np.log10(loss_history))
        training_loss_history.append(loss_history)
        
        if j % 10 == 0:
            print("Time on function: {}".format(time.time() - t))
            
    print("Loss on {}: {}; {}".format(i, loss, loss_history[-1]))
        
    lr.set_value((lr.get_value() * 0.7).astype(np.float32))
        
plt.plot(np.mean(training_loss_history, axis=0))
# Out:
# Time on function: 0.3452332019805908
# Time on function: 0.26808905601501465
# Time on function: 0.29587340354919434
# Time on function: 0.3034932613372803
# Time on function: 0.2911407947540283
# Time on function: 0.25417590141296387
# Time on function: 0.31403684616088867
# Time on function: 0.26094532012939453
# Time on function: 0.27586984634399414
# Time on function: 0.3602728843688965
# Loss on 0: -713.5851457118988; 0.007091098930686712
# Time on function: 0.2593576908111572
# Time on function: 0.365398645401001
# Time on function: 0.25809812545776367
# Time on function: 0.3632369041442871
# Time on function: 0.26965951919555664
# Time on function: 0.3373687267303467
# Time on function: 0.37762904167175293
# Time on function: 0.3479025363922119
# Time on function: 0.3259096145629883
# Time on function: 0.33360743522644043
# Loss on 1: -914.0653285980225; 0.0021341980900615454
# Time on function: 0.30727672576904297
# Time on function: 0.2748839855194092
# Time on function: 0.2794308662414551
# Time on function: 0.28832006454467773
# Time on function: 0.30334949493408203
# Time on function: 0.27121567726135254
# Time on function: 0.2724423408508301
# Time on function: 0.3040504455566406
# Time on function: 0.29299211502075195
# Time on function: 0.29615139961242676
# Loss on 2: -1088.0726811885834; 0.001338841044344008
# Time on function: 0.33382701873779297
# Time on function: 0.29028797149658203
# Time on function: 0.30008554458618164
# Time on function: 0.3023402690887451
# Time on function: 0.2908670902252197
# Time on function: 0.3585224151611328
# Time on function: 0.32106995582580566
# Time on function: 0.2840862274169922
# Time on function: 0.3769493103027344
# Time on function: 0.3598511219024658
# Loss on 3: -799.9929180145264; 0.006836106069386005
# Time on function: 0.30142784118652344
# Time on function: 0.2696685791015625
# Time on function: 0.28975582122802734
# Time on function: 0.28560781478881836
# Time on function: 0.3334949016571045
# Time on function: 0.26140403747558594
# Time on function: 0.2565131187438965
# Time on function: 0.2674520015716553
# Time on function: 0.4008941650390625
# Time on function: 0.32588815689086914
# Loss on 4: -1299.2894034385681; 0.00014351429126691073
# Time on function: 0.3148386478424072
# Time on function: 0.2565019130706787
# Time on function: 0.3444325923919678
# Time on function: 0.35968804359436035
# Time on function: 0.22390317916870117
# Time on function: 0.4609506130218506
# Time on function: 0.47123098373413086
# Time on function: 0.46065330505371094
# Time on function: 0.466933012008667
# Time on function: 0.4641866683959961
# Loss on 5: -1094.8233630657196; 0.0006156897870823741
# Time on function: 1.0633666515350342
# Time on function: 1.0705699920654297
# Time on function: 0.4873189926147461
# Time on function: 0.6210298538208008
# Time on function: 0.2623610496520996
# Time on function: 0.8143389225006104
# Time on function: 1.1835384368896484
# Time on function: 0.8066987991333008
# Time on function: 1.1688237190246582
# Time on function: 0.275054931640625
# Loss on 6: -1723.0184469223022; 7.930472747830208e-06
# Time on function: 1.0670299530029297
# Time on function: 0.24989700317382812
# Time on function: 0.29118943214416504
# Time on function: 0.5208649635314941
# Time on function: 0.5164568424224854
# Time on function: 0.34011411666870117
# Time on function: 0.25136613845825195
# Time on function: 0.2615184783935547
# Time on function: 0.26195836067199707
# Time on function: 0.5192239284515381
# Loss on 7: -1172.6381237506866; 0.00039205464418046176
# Time on function: 0.26064300537109375
# Time on function: 0.515817403793335
# Time on function: 0.2803361415863037
# Time on function: 0.5417251586914062
# Time on function: 0.6407666206359863
# Time on function: 0.48449254035949707
# Time on function: 0.42971062660217285
# Time on function: 0.34435081481933594
# Time on function: 0.28660130500793457
# Time on function: 0.2604053020477295
# Loss on 8: -1366.621775150299; 9.624801896279678e-05
# Time on function: 0.2621004581451416
# Time on function: 0.2624185085296631
# Time on function: 0.47965121269226074
# Time on function: 0.5686540603637695
# Time on function: 0.4735989570617676
# Time on function: 0.4819166660308838
# Time on function: 0.6816666126251221
# Time on function: 0.47571420669555664
# Time on function: 0.5177972316741943
# Time on function: 0.2597770690917969
# Loss on 9: -2236.1746485233307; 8.690030028901674e-08
# Time on function: 0.2643265724182129
# Time on function: 0.5229372978210449
# Time on function: 0.5493507385253906
# Time on function: 0.520869255065918
# Time on function: 0.5090105533599854
# Time on function: 0.25383567810058594
# Time on function: 0.2561945915222168
# Time on function: 0.2942240238189697
# Time on function: 0.5109481811523438
# Time on function: 0.461733341217041
# Loss on 10: -1894.624763250351; 1.6930588344621356e-06
# Time on function: 0.2592580318450928
# Time on function: 0.45236802101135254
# Time on function: 0.2593982219696045
# Time on function: 0.48406386375427246
# Time on function: 0.5023019313812256
# Time on function: 0.2587594985961914
# Time on function: 0.2590978145599365
# Time on function: 0.2905004024505615
# Time on function: 0.25966310501098633
# Time on function: 0.2636094093322754
# Loss on 11: -2122.1785712242126; 2.987186746850057e-07
# Time on function: 0.2567298412322998
# Time on function: 0.2732536792755127
# Time on function: 0.2560408115386963
# Time on function: 0.2604553699493408
# Time on function: 0.2616610527038574
# Time on function: 0.25188112258911133
# Time on function: 0.24323153495788574
# Time on function: 0.2454233169555664
# Time on function: 0.2518637180328369
# Time on function: 0.27779507637023926
# Loss on 12: -1812.6621465682983; 2.973013806695235e-06
# Time on function: 0.4332125186920166
# Time on function: 0.263352632522583
# Time on function: 0.39658379554748535
# Time on function: 0.24805927276611328
# Time on function: 0.2634139060974121
# Time on function: 0.26170778274536133
# Time on function: 0.265214204788208
# Time on function: 0.2632479667663574
# Time on function: 0.26364850997924805
# Time on function: 0.284409761428833
# Loss on 13: -1825.225103855133; 3.1485024010180496e-06
# Time on function: 0.3694009780883789
# Time on function: 0.5195515155792236
# Time on function: 0.4825437068939209
# Time on function: 1.10445237159729
# Time on function: 0.6102895736694336
# Time on function: 0.4611208438873291
# Time on function: 0.46607303619384766
# Time on function: 1.1460974216461182
# Time on function: 0.656571626663208
# Time on function: 0.48485493659973145
# Loss on 14: -1878.3676421642303; 1.7672143712843535e-06
# Time on function: 0.5562121868133545
# Time on function: 0.25450944900512695
# Time on function: 0.2627096176147461
# Time on function: 0.25849342346191406
# Time on function: 0.2538466453552246
# Time on function: 0.25502514839172363
# Time on function: 0.2521800994873047
# Time on function: 0.4019026756286621
# Time on function: 0.3325011730194092
# Time on function: 0.4892542362213135
# Loss on 15: -2134.2208943367004; 2.0366969977203553e-07
# Time on function: 0.3896775245666504
# Time on function: 0.2654881477355957
# Time on function: 0.2606163024902344
# Time on function: 0.27895116806030273
# Time on function: 0.26315903663635254
# Time on function: 0.5344831943511963
# Time on function: 0.4954648017883301
# Time on function: 0.4701709747314453
# Time on function: 0.4716663360595703
# Time on function: 0.46915149688720703
# Loss on 16: -2254.797212123871; 8.958014774407275e-08
# Time on function: 0.5044374465942383
# Time on function: 0.4688901901245117
# Time on function: 0.4585113525390625
# Time on function: 0.9702646732330322
# Time on function: 1.1899659633636475
# Time on function: 0.5319595336914062
# Time on function: 0.5095629692077637
# Time on function: 0.2532832622528076
# Time on function: 0.26517510414123535
# Time on function: 0.2548482418060303
# Loss on 17: -2755.7854685783386; 1.2683898376053548e-09
# Time on function: 0.25560927391052246
# Time on function: 0.26273584365844727
# Time on function: 0.4821000099182129
# Time on function: 0.2879514694213867
# Time on function: 0.3037540912628174
# Time on function: 0.2512214183807373
# Time on function: 0.25161147117614746
# Time on function: 0.30003881454467773
# Time on function: 0.3685483932495117
# Time on function: 0.46230602264404297
# Loss on 18: -3050.8552849292755; 4.26451512991477e-11
# Time on function: 0.4604320526123047
# Time on function: 0.4554927349090576
# Time on function: 0.4617438316345215
# Time on function: 0.4233851432800293
# Time on function: 0.29196906089782715
# Time on function: 0.27170228958129883
# Time on function: 0.26481080055236816
# Time on function: 1.0235753059387207
# Time on function: 0.26037049293518066
# Time on function: 0.29596757888793945
# Loss on 19: -2502.363027572632; 1.33496831367097e-08

# %%
print(lr.get_value())
lr.set_value(0.001)
# Out:
# 8.881784618863365e-19

# %%
print(loss_fn(np.zeros(2, dtype=np.float32), 300, a_, b_)[1][-1])
# Out:
# 1.11792e-08

# %%
print(a_, b_)
plt.plot(loss_fn(np.zeros(2, dtype=np.float32), 300, a_, b_)[1])
# Out:
# 1.0 2.0442495346069336

# %%
train_history = momentum_fn(np.zeros(2, dtype=np.float32), 300, a_, b_, 6.0)[1]

# %%
plt.plot(loss_fn(np.zeros(2, dtype=np.float32), 300, a_, b_)[1], label='lstm')
plt.plot(train_history, label='gd')
plt.legend();

# %%
from IPython import display

training_loss_history = []
training_loss_history_gd = []
training_loss_history_momentum = []

histories_gd = {lrate: [] for lrate in np.logspace(-3, 3, num=15)}
histories_momentum = {lrate: [] for lrate in np.logspace(-3, 3, num=15)}

for i in range(50):
    #a_ = np.cast['float32'](np.random.rand() * 10)
    a_ = 1.
    b_ = np.cast['float32'](np.random.rand() * 10)
    theta = np.zeros(2, dtype=np.float32)
    
    losses = loss_fn(theta, 500, a_, b_)[1]
    loss = sum(losses)
    training_loss_history.append(losses)
    
    for lrate in histories_gd.keys():
        train_history = sgd_fn(theta, 500, a_, b_, lrate)[1]
        histories_gd[lrate].append(np.array(train_history))

        train_history = momentum_fn(theta, 500, a_, b_, lrate)[1]
        histories_momentum[lrate].append(np.array(train_history))
    
    if i % 5 == 0:
        print("Loss on {}: {}".format(i, loss))
# Out:
# Loss on 0: 0.001400359754700209
# Loss on 5: 0.0012197259222430645
# Loss on 10: 0.0014463877149998305
# Loss on 15: 0.0012010469238188382
# Loss on 20: 0.0010737622178742523
# Loss on 25: 0.0011220445290799491
# Loss on 30: 0.0010626961140072222
# Loss on 35: 0.0012727482305131543
# Loss on 40: 0.001144271691421235
# Loss on 45: 0.0015221142079850924

# %%
plt.figure(figsize=(15, 12))
plt.plot(np.mean(training_loss_history, axis=0), label='lstm')
# for lrate, history in histories_gd.items():
#     if lrate < 1e2:
#         plt.plot(np.mean(history, axis=0), label='gd; lr={}'.format(lrate))
for lrate, history in histories_momentum.items():
    if lrate < 1e1:
        plt.plot(np.mean(history, axis=0), label='momentum; lr={}'.format(lrate))
plt.legend();

# %%
plt.figure(figsize=(15, 12))
plt.title('Mean loss history over 1000 steps over 100 random quadratic functions')
plt.xlabel('step')
plt.ylabel('loss')
#plt.plot(np.log(np.mean(training_loss_history, axis=0)), label='lstm')
plt.semilogy(np.median(training_loss_history, axis=0), label='lstm')
# for lrate, history in histories_gd.items():
#     if lrate < 1e2:
#         #plt.plot(np.log(np.mean(history, axis=0)), label='gd; lr={}'.format(lrate))
#         plt.semilogy(np.mean(history, axis=0), label='gd; lr={}'.format(lrate))
for lrate, history in histories_momentum.items():
    if lrate < 5e1:
        #plt.plot(np.log(np.mean(history, axis=0)), label='momentum; lr={}'.format(lrate))
        plt.semilogy(np.median(history, axis=0), label='momentum; lr={}'.format(lrate))
plt.legend();

# %%
#a_ = np.cast['float32'](np.random.rand() * 10)
b_ = np.cast['float32'](np.random.rand() * 10)
a_ = np.cast['float32'](5.)
b_ = np.cast['float32'](100.)
theta = np.zeros(2, dtype=np.float32)

lstm_history, lstm_losses = loss_fn(theta, 100, a_, b_)
lstm_history = np.concatenate([theta.reshape(1, -1), lstm_history], axis=0)
lstm_loss = sum(lstm_losses)

pts_hst = {}

for lrate in np.logspace(-3, 3, 15):
#     if lrate >= 1e2:
#         continue
        
    sgd_points, sgd_losses = sgd_fn(theta, 100, a_, b_, lrate)
    sdg_points = [theta] + sgd_points
    
    pts_hst[lrate] = (sgd_points, sgd_losses)
    
    sgd_points, sgd_losses = momentum_fn(theta, 100, a_, b_, lrate)
    sdg_points = [theta] + sgd_points
    
    pts_hst[lrate] = (sgd_points, sgd_losses)

# %%
min_x = min(min(lstm_history.T[0]), 1.2*a_)
max_x = max(max(lstm_history.T[0]), 1.2*a_)
min_y = min(min(lstm_history.T[1]), 1.2*a_**2)
max_y = max(max(lstm_history.T[1]), 1.2*a_**2)

delta_x = (max_x - min_x) / 100.
delta_y = (max_y - min_y) / 100.

#x = np.arange(2 * min_x - (min_x + max_x) / 2, 2 * max_x - (min_x + max_x) / 2, delta_x)
#y = np.arange(2 * min_y - (min_y + max_y) / 2, 2 * max_y - (min_y + max_y) / 2, delta_y)
x = np.arange(min_x, max_x, delta_x)
y = np.arange(min_y, max_y, delta_y)
X, Y = np.meshgrid(x, y)

Z = (a_ - X)**2 + b_ * (Y - X**2)**2

plt.figure(figsize=(15, 12))
plt.title('Trajectory')

CS = plt.contour(X, Y, Z)
plt.clabel(CS, inline=1, fontsize=10)

plt.plot([a_], [a_**2], marker='x', color='k')

plt.xlabel('x1')
plt.ylabel('x2')
plt.plot(lstm_history.T[0], lstm_history.T[1], marker='o', label='lstm')
for lrate in np.logspace(-3, 3, 15):
    if lrate <= 5:
        hist, _ = pts_hst[lrate]
        plt.plot(np.array(hist).T[0], np.array(hist).T[1], label='momentum; {}'.format(lrate), marker='o')
plt.legend(loc=2);

# %%
plt.figure(figsize=(15, 12))
plt.title('loss/step')
plt.xlabel('step')
plt.ylabel('loss')
plt.plot(lstm_losses, label='lstm')
for lrate in np.logspace(-3, 3, 15):
    if lrate < 5:
        _, lss = pts_hst[lrate]
        plt.plot(lss, label='momentum; {}'.format(lrate))
plt.legend();

# %%
plt.figure(figsize=(15, 12))
plt.title('log(loss)/step')
plt.xlabel('step')
plt.ylabel('log(loss)')
# plt.plot(np.log10(lstm_losses), label='lstm')
plt.semilogy(lstm_losses, label='lstm')
for lrate in np.logspace(-3, 3, 15):
    if lrate < 5:
        _, lss = pts_hst[lrate]
#         plt.plot(np.log(lss), label='momentum; {}'.format(lrate))
        plt.semilogy(lss, label='momentum; {}'.format(lrate))
plt.legend();

# plt.semilogy(lstm_losses)

# %%
print(a_, b_)
# Out:
# 1.0 1.7816828489303589

# %%
a_, b_ = 1.0, 0.023357493802905083
